# %% [markdown]
# Write a python program to find the area of an ellipse by double integration A = $4\int_0^a\int_0^{(b/a)\sqrt{(a^2 - x^2)}}\, dydx$

# %%
from sympy import *
x=Symbol('x')
y=Symbol('y')
a=4
b=6
w3=4*integrate(1,(y,0,(b/a)*sqrt(a**2-x**2)),(x,0,a))
print(w3)
# Out:
# 24.0*pi
