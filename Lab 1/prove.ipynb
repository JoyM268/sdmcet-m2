# %%
from sympy import *
x,y,z=symbols('x y z')
w3=integrate(x**2+y**2,y,x)
pprint(w3)
w4=integrate(x**2+y**2,x,y)
pprint(w4)
# Out:
#  3        3
# x ⋅y   x⋅y
# ──── + ────
#  3      3
#  3        3
# x ⋅y   x⋅y
# ──── + ────
#  3      3
